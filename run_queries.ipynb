# %%
import pandas as pd
import duckdb

# %%
sql_query = '''
SELECT * FROM usa_cars_datasets LIMIT 10;
'''

with duckdb.connect("C:/Users/TOMLA/PycharmProjects/lb/usa_cars/dev.duckdb") as con:
    display(con.sql(sql_query).df())
# Out:
#    a  price      brand    model  year   title_status  mileage   color  \
# 0  0   6300     toyota  cruiser  2008  clean vehicle   274117   black
# 1  1   2899       ford       se  2011  clean vehicle   190552  silver
# 2  2   5350      dodge      mpv  2018  clean vehicle    39590  silver
# 3  3  25000       ford     door  2014  clean vehicle    64146    blue
# 4  4  27700  chevrolet     1500  2018  clean vehicle     6654     red
# 5  5   5700      dodge      mpv  2018  clean vehicle    45561   white
# 6  6   7300  chevrolet       pk  2010  clean vehicle   149050   black
# 7  7  13350        gmc     door  2017  clean vehicle    23525    gray
# 8  8  14600  chevrolet   malibu  2018  clean vehicle     9371  silver
# 9  9   5250       ford      mpv  2017  clean vehicle    63418   black
#
#                    vin        lot       state country      condition
# 0    jtezu11f88k007763  159348797  new jersey     usa   10 days left
# 1    2fmdk3gc4bbb02217  166951262   tennessee     usa    6 days left
# 2    3c4pdcgg5jt346413  167655728     georgia     usa    2 days left
# 3    1ftfw1et4efc23745  167753855    virginia     usa  22 hours left
# 4    3gcpcrec2jg473991  167763266     florida     usa  22 hours left
# 5    2c4rdgeg9jr237989  167655771       texas     usa    2 days left
# 6    1gcsksea1az121133  167753872     georgia     usa  22 hours left
# 7    1gks2gkc3hr326762  167692494  california     usa  20 hours left
# 8    1g1zd5st5jf191860  167763267     florida     usa  22 hours left
# 9    2fmpk3j92hbc12542  167656121       texas     usa    2 days left

# %%
sql_query = '''
SELECT * FROM all_cars;
'''

with duckdb.connect("C:/Users/TOMLA/PycharmProjects/lb/usa_cars/dev.duckdb") as con:
    display(con.sql(sql_query).df())
# Out:
#          a  price      brand    model  year   title_status  mileage   color  \
# 0        0   6300     toyota  cruiser  2008  clean vehicle   274117   black
# 1        1   2899       ford       se  2011  clean vehicle   190552  silver
# 2        2   5350      dodge      mpv  2018  clean vehicle    39590  silver
# 3        3  25000       ford     door  2014  clean vehicle    64146    blue
# 4        4  27700  chevrolet     1500  2018  clean vehicle     6654     red
# ...    ...    ...        ...      ...   ...            ...      ...     ...
# 2494  2494   7800     nissan    versa  2019  clean vehicle    23609     red
# 2495  2495   9200     nissan    versa  2018  clean vehicle    34553  silver
# 2496  2496   9200     nissan    versa  2018  clean vehicle    31594  silver
# 2497  2497   9200     nissan    versa  2018  clean vehicle    32557   black
# 2498  2498   9200     nissan    versa  2018  clean vehicle    31371  silver
#
#                       vin        lot       state country      condition
# 0       jtezu11f88k007763  159348797  new jersey     usa   10 days left
# 1       2fmdk3gc4bbb02217  166951262   tennessee     usa    6 days left
# 2       3c4pdcgg5jt346413  167655728     georgia     usa    2 days left
# 3       1ftfw1et4efc23745  167753855    virginia     usa  22 hours left
# 4       3gcpcrec2jg473991  167763266     florida     usa  22 hours left
# ...                   ...        ...         ...     ...            ...
# 2494    3n1cn7ap9kl880319  167722715  california     usa    1 days left
# 2495    3n1cn7ap5jl884088  167762225     florida     usa  21 hours left
# 2496    3n1cn7ap9jl884191  167762226     florida     usa  21 hours left
# 2497    3n1cn7ap3jl883263  167762227     florida     usa    2 days left
# 2498    3n1cn7ap4jl884311  167762228     florida     usa  21 hours left
#
# [2499 rows x 13 columns]

# %%
sql_query = '''
SELECT * FROM brand_model_stats;
'''

with duckdb.connect("C:/Users/TOMLA/PycharmProjects/lb/usa_cars/dev.duckdb") as con:
    display(con.sql(sql_query).df())
# Out:
#          brand     model  min_year  max_year  median_year  min_mileage  \
# 0        buick    encore      2016      2018       2017.0        19655
# 1     chrysler       300      2017      2019       2019.0        31311
# 2          bmw      door      2000      2017       2013.0        17626
# 3    chevrolet     tahoe      2015      2020       2019.0        13303
# 4    chevrolet  suburban      2017      2019       2018.5        11135
# ..         ...       ...       ...       ...          ...          ...
# 175    hyundai   elantra      2017      2017       2017.0        35687
# 176        kia  sportage      2017      2017       2017.0        71991
# 177   cadillac       xt5      2019      2019       2019.0        16013
# 178  chevrolet     spark      2018      2018       2018.0        42561
# 179     nissan    murano      2016      2018       2018.0        17127
#
#      max_mileage  median_mileage  min_price  max_price  median_price
# 0          60171         20002.0      13200      16500       13500.0
# 1          42648         36693.5      18300      19600       19350.0
# 2         216657         46060.0          0      24500        6200.0
# 3         125507         36198.0      21200      45500       37500.0
# 4          52618         42674.5      29500      38500       33350.0
# ..           ...             ...        ...        ...           ...
# 175        35687         35687.0       9800       9800        9800.0
# 176        71991         71991.0      13000      13000       13000.0
# 177        16013         16013.0      37500      37500       37500.0
# 178        42561         42561.0       7200       7200        7200.0
# 179        59640         36844.0      15200      24000       21400.0
#
# [180 rows x 11 columns]

# %%
sql_query = '''
SELECT * FROM high_value_cars;
'''

with duckdb.connect("C:/Users/TOMLA/PycharmProjects/lb/usa_cars/dev.duckdb") as con:
    display(con.sql(sql_query).df())
# Out:
#         a  price     brand     model  year       title_status  mileage  \
# 0     399  61200       bmw    series  2020      clean vehicle     7509
# 1    2088  59900      ford       max  2020      clean vehicle     2162
# 2     426  55600     lexus        gx  2020      clean vehicle     8186
# 3    1701  46900      ford  explorer  2020      clean vehicle      740
# 4    1340  74000      ford       drw  2019      clean vehicle    10536
# ..    ...    ...       ...       ...   ...                ...      ...
# 252   185   1400     dodge        pk  2002      clean vehicle   185460
# 253   200   5000     dodge    pickup  2001      clean vehicle   109360
# 254   188    175  chrysler      door  2000  salvage insurance   231240
# 255   395     25      ford      door  1998  salvage insurance   300021
# 256   362     25      ford    pickup  1994  salvage insurance   206162
#
#         color                  vin        lot           state country  \
# 0       black    wba7t2c04lgl17687  167417053      california     usa
# 1    no_color    1fmjk2at4lea11492  167762991            ohio     usa
# 2      silver    jtjam7bx4l5251250  167605747         florida     usa
# 3        gray    1fmsk8fh3lga11841  167751303        virginia     usa
# 4    no_color    1ft8w4dt6ked32656  167780682        illinois     usa
# ..        ...                  ...        ...             ...     ...
# 252     black    1b7hg38n62s587845  167756423        michigan     usa
# 253     white    1b7hc16x01s213315  167756836         georgia     usa
# 254       red    2c3hd46r3yh208325  167756464  north carolina     usa
# 255     brown    1ftzx0766wka18481  167611660        arkansas     usa
# 256     white    1ftdf15y2rnb12612  167361489         georgia     usa
#
#          condition  year_price_percentile
# 0      7 days left               1.000000
# 1    21 hours left               0.978723
# 2      2 days left               0.957447
# 3    21 hours left               0.936170
# 4      2 days left               1.000000
# ..             ...                    ...
# 252    2 days left               1.000000
# 253  21 hours left               1.000000
# 254    3 days left               1.000000
# 255  17 hours left               1.000000
# 256    2 days left               1.000000
#
# [257 rows x 14 columns]
